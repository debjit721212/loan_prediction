# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.8

# %%
# !pip uninstall pandas -y

# !pip install -U pandas

# !pip uninstall numpy -y

# !pip install -U numpy
# Out:
# Found existing installation: pandas 1.3.4
# Uninstalling pandas-1.3.4:
#   Successfully uninstalled pandas-1.3.4
# ...
#   Using cached pandas-1.3.4-cp38-cp38-win_amd64.whl (10.2 MB)
# ...
# Found existing installation: numpy 1.21.3
# Uninstalling numpy-1.21.3:
#   Successfully uninstalled numpy-1.21.3
# ...
#   Using cached numpy-1.21.3-cp38-cp38-win_amd64.whl (14.0 MB)
# ...

# %%
import pandas as pd 
import numpy as np

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
np.__version__
# Out:
# '1.21.3'

# %%
df = pd.read_csv("train_folds.csv")

# %%
df.head()
# Out:
#    Id   Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0   1  1303834   23           3         single          rented            no
# 1   2  7574516   40          10         single          rented            no
# 2   3  3991815   66           4        married          rented            no
# 3   4  6256451   41           2         single          rented           yes
# 4   5  5768871   47          11         single          rented            no
#
#             Profession                 CITY           STATE  CURRENT_JOB_YRS  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh                3
# 1   Software_Developer             Parbhani     Maharashtra                9
# 2     Technical_writer            Alappuzha          Kerala                4
# 3   Software_Developer          Bhubaneswar          Odisha                2
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu                3
#
#    CURRENT_HOUSE_YRS  Risk_Flag  skfold
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Income', 'Age', 'Experience', 'Married/Single',
#        'House_Ownership', 'Car_Ownership', 'Profession', 'CITY', 'STATE',
#        'CURRENT_JOB_YRS', 'CURRENT_HOUSE_YRS', 'Risk_Flag', 'skfold'],
#       dtype='object')

# %%
df["Status"] = df['Married/Single']

# %%
df.head()
# Out:
#    Id   Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0   1  1303834   23           3         single          rented            no
# 1   2  7574516   40          10         single          rented            no
# 2   3  3991815   66           4        married          rented            no
# 3   4  6256451   41           2         single          rented           yes
# 4   5  5768871   47          11         single          rented            no
#
#             Profession                 CITY           STATE  CURRENT_JOB_YRS  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh                3
# 1   Software_Developer             Parbhani     Maharashtra                9
# 2     Technical_writer            Alappuzha          Kerala                4
# 3   Software_Developer          Bhubaneswar          Odisha                2
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu                3
#
# ...

# %%
df = df.drop(columns=["Id", "Married/Single"], axis =1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     Income  Age  Experience House_Ownership Car_Ownership  \
# 0  1303834   23           3          rented            no
# 1  7574516   40          10          rented            no
# 2  3991815   66           4          rented            no
# 3  6256451   41           2          rented           yes
# 4  5768871   47          11          rented            no
#
#             Profession                 CITY           STATE  CURRENT_JOB_YRS  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh                3
# 1   Software_Developer             Parbhani     Maharashtra                9
# 2     Technical_writer            Alappuzha          Kerala                4
# 3   Software_Developer          Bhubaneswar          Odisha                2
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu                3
#
#    CURRENT_HOUSE_YRS  Risk_Flag  skfold   Status
# 0                 13          0       3   single
# 1                 13          0       0   single
# ...

# %%
df['House_Ownership'].unique()
# Out:
# array(['rented', 'norent_noown', 'owned'], dtype=object)

# %%
df['Car_Ownership'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['Profession'].unique()
# Out:
# array(['Mechanical_engineer', 'Software_Developer', 'Technical_writer',
#        'Civil_servant', 'Librarian', 'Economist', 'Flight_attendant',
#        'Architect', 'Designer', 'Physician', 'Financial_Analyst',
#        'Air_traffic_controller', 'Politician', 'Police_officer', 'Artist',
#        'Surveyor', 'Design_Engineer', 'Chemical_engineer',
#        'Hotel_Manager', 'Dentist', 'Comedian', 'Biomedical_Engineer',
#        'Graphic_Designer', 'Computer_hardware_engineer',
#        'Petroleum_Engineer', 'Secretary', 'Computer_operator',
#        'Chartered_Accountant', 'Technician', 'Microbiologist',
#        'Fashion_Designer', 'Aviator', 'Psychologist', 'Magistrate',
#        'Lawyer', 'Firefighter', 'Engineer', 'Official', 'Analyst',
#        'Geologist', 'Drafter', 'Statistician', 'Web_designer',
#        'Consultant', 'Chef', 'Army_officer', 'Surgeon', 'Scientist',
#        'Civil_engineer', 'Industrial_Engineer', 'Technology_specialist'],
#       dtype=object)

# %%
df['CITY'].unique()
# Out:
# array(['Rewa', 'Parbhani', 'Alappuzha', 'Bhubaneswar',
#        'Tiruchirappalli[10]', 'Jalgaon', 'Tiruppur', 'Jamnagar',
#        'Kota[6]', 'Karimnagar', 'Hajipur[31]', 'Adoni', 'Erode[17]',
#        'Kollam', 'Madurai', 'Anantapuram[24]', 'Kamarhati', 'Bhusawal',
#        'Sirsa', 'Amaravati', 'Secunderabad', 'Ahmedabad', 'Ajmer',
#        'Ongole', 'Miryalaguda', 'Ambattur', 'Indore', 'Pondicherry',
#        'Shimoga', 'Chennai', 'Gulbarga', 'Khammam', 'Saharanpur',
#        'Gopalpur', 'Amravati', 'Udupi', 'Howrah', 'Aurangabad[39]',
#        'Hospet', 'Shimla', 'Khandwa', 'Bidhannagar', 'Bellary', 'Danapur',
#        'Purnia[26]', 'Bijapur', 'Patiala', 'Malda', 'Sagar', 'Durgapur',
#        'Junagadh', 'Singrauli', 'Agartala', 'Thanjavur', 'Hindupur',
#        'Naihati', 'North_Dumdum', 'Panchkula', 'Anantapur', 'Serampore',
#        'Bathinda', 'Nadiad', 'Kanpur', 'Haridwar', 'Berhampur',
#        'Jamshedpur', 'Hyderabad', 'Bidar', 'Kottayam', 'Solapur',
# ...

# %%
df["CITY"].replace({"Kota[6]": "Kota", "Hajipur[31]": "Hajipur","Erode[17]": "Erode",
                    "Aurangabad[39]": "Aurangabad", "Anantapuram[24]": "Anantapuram", "Purnia[26]": "Purnia",
                    "Eluru[25]": "Eluru", "Siwan[32]": "Siwan", "Motihari[34]":"Motihari", "Warangal[11][12]": "Warangal",
                   "Jehanabad[38]": "Jehanabad", "Kishanganj[35]": "Kishanganj", "Tirupati[21][22]": "Tirupati",
                    "Tirupati[21][22]":"Tirupati","Kurnool[18]": "Kurnool", "Kadapa[23]": "Kadapa", "Jammu[16]": "Jammu",
                    "Rajahmundry[19][20]": "Rajahmundry" ,"Saharsa[29]": "Saharsa", "Jamalpur[36]": "Jamalpur",
                    "Dehri[30]":"Dehri","Nellore[14][15]":"Nellore","Visakhapatnam[4]": "Visakhapatnam", "Buxar[37]": "Buxar",
                    "Ramagundam[27]": "Ramagundam", "Sasaram[30]": "Sasaram","Guntur[13]": "Guntur", "Chittoor[28]":"Chittoor",
                    "Bettiah[33]":"Bettiah", "Mysore[7][8][9]":"Mysore","Tiruchirappalli[10]":"Tiruchirappalli",}, inplace=True)
print(df)
# Out:
#          Income  Age  Experience House_Ownership Car_Ownership  \
# 0       1303834   23           3          rented            no
# 1       7574516   40          10          rented            no
# 2       3991815   66           4          rented            no
# 3       6256451   41           2          rented           yes
# 4       5768871   47          11          rented            no
# ...         ...  ...         ...             ...           ...
# 251995  8154883   43          13          rented            no
# 251996  2843572   26          10          rented            no
# 251997  4522448   46           7          rented            no
# 251998  6507128   45           0          rented            no
# 251999  9070230   70          17          rented            no
#
#                  Profession             CITY           STATE  CURRENT_JOB_YRS  \
# 0       Mechanical_engineer             Rewa  Madhya_Pradesh                3
# ...

# %%
df['CITY'].unique()
# Out:
# array(['Rewa', 'Parbhani', 'Alappuzha', 'Bhubaneswar', 'Tiruchirappalli',
#        'Jalgaon', 'Tiruppur', 'Jamnagar', 'Kota', 'Karimnagar', 'Hajipur',
#        'Adoni', 'Erode', 'Kollam', 'Madurai', 'Anantapuram', 'Kamarhati',
#        'Bhusawal', 'Sirsa', 'Amaravati', 'Secunderabad', 'Ahmedabad',
#        'Ajmer', 'Ongole', 'Miryalaguda', 'Ambattur', 'Indore',
#        'Pondicherry', 'Shimoga', 'Chennai', 'Gulbarga', 'Khammam',
#        'Saharanpur', 'Gopalpur', 'Amravati', 'Udupi', 'Howrah',
#        'Aurangabad', 'Hospet', 'Shimla', 'Khandwa', 'Bidhannagar',
#        'Bellary', 'Danapur', 'Purnia', 'Bijapur', 'Patiala', 'Malda',
#        'Sagar', 'Durgapur', 'Junagadh', 'Singrauli', 'Agartala',
#        'Thanjavur', 'Hindupur', 'Naihati', 'North_Dumdum', 'Panchkula',
#        'Anantapur', 'Serampore', 'Bathinda', 'Nadiad', 'Kanpur',
#        'Haridwar', 'Berhampur', 'Jamshedpur', 'Hyderabad', 'Bidar',
#        'Kottayam', 'Solapur', 'Suryapet', 'Aizawl', 'Asansol', 'Deoghar',
# ...

# %%
df['STATE'].unique()
# Out:
# array(['Madhya_Pradesh', 'Maharashtra', 'Kerala', 'Odisha', 'Tamil_Nadu',
#        'Gujarat', 'Rajasthan', 'Telangana', 'Bihar', 'Andhra_Pradesh',
#        'West_Bengal', 'Haryana', 'Puducherry', 'Karnataka',
#        'Uttar_Pradesh', 'Himachal_Pradesh', 'Punjab', 'Tripura',
#        'Uttarakhand', 'Jharkhand', 'Mizoram', 'Assam',
#        'Jammu_and_Kashmir', 'Delhi', 'Chhattisgarh', 'Chandigarh',
#        'Uttar_Pradesh[5]', 'Manipur', 'Sikkim'], dtype=object)

# %%
df['Status'].unique()
# Out:
# array(['single', 'married'], dtype=object)

# %%
df['Status'].value_counts()
# Out:
# single     226272
# married     25728
# Name: Status, dtype: int64

# %%
df['STATE'].value_counts()
# Out:
# Uttar_Pradesh        28400
# Maharashtra          25562
# Andhra_Pradesh       25297
# West_Bengal          23483
# Bihar                19780
# Tamil_Nadu           16537
# Madhya_Pradesh       14122
# Karnataka            11855
# Gujarat              11408
# Rajasthan             9174
# Jharkhand             8965
# Haryana               7890
# Telangana             7524
# Assam                 7062
# Kerala                5805
# Delhi                 5490
# Punjab                4720
# Odisha                4658
# Chhattisgarh          3834
# Uttarakhand           1874
# Jammu_and_Kashmir     1780
# Puducherry            1433
# Mizoram                849
# Manipur                849
# Himachal_Pradesh       833
# Tripura                809
# Uttar_Pradesh[5]       743
# Chandigarh             656
# Sikkim                 608
# Name: STATE, dtype: int64

# %%
df["STATE"].replace({"Uttar_Pradesh[5]": "Uttar_Pradesh"}, inplace=True)
print(df)
# Out:
#          Income  Age  Experience House_Ownership Car_Ownership  \
# 0       1303834   23           3          rented            no
# 1       7574516   40          10          rented            no
# 2       3991815   66           4          rented            no
# 3       6256451   41           2          rented           yes
# 4       5768871   47          11          rented            no
# ...         ...  ...         ...             ...           ...
# 251995  8154883   43          13          rented            no
# 251996  2843572   26          10          rented            no
# 251997  4522448   46           7          rented            no
# 251998  6507128   45           0          rented            no
# 251999  9070230   70          17          rented            no
#
#                  Profession             CITY           STATE  CURRENT_JOB_YRS  \
# 0       Mechanical_engineer             Rewa  Madhya_Pradesh                3
# ...

# %%
df['STATE'].value_counts()
# Out:
# Uttar_Pradesh        29143
# Maharashtra          25562
# Andhra_Pradesh       25297
# West_Bengal          23483
# Bihar                19780
# Tamil_Nadu           16537
# Madhya_Pradesh       14122
# Karnataka            11855
# Gujarat              11408
# Rajasthan             9174
# Jharkhand             8965
# Haryana               7890
# Telangana             7524
# Assam                 7062
# Kerala                5805
# Delhi                 5490
# Punjab                4720
# Odisha                4658
# Chhattisgarh          3834
# Uttarakhand           1874
# Jammu_and_Kashmir     1780
# Puducherry            1433
# Manipur                849
# Mizoram                849
# Himachal_Pradesh       833
# Tripura                809
# Chandigarh             656
# Sikkim                 608
# Name: STATE, dtype: int64

# %%
df['CITY'].value_counts()
# Out:
# Aurangabad       1543
# Vijayanagaram    1259
# Bhopal           1208
# Bulandshahr      1185
# Saharsa          1180
#                  ...
# Ujjain            486
# Warangal          459
# Bettiah           457
# Katni             448
# Karaikudi         431
# Name: CITY, Length: 316, dtype: int64

# %% [markdown]
# Here i see that one state Uttar_Pradesh[5] is we have to include in uttar_Pradesh

# %%
df['Profession'].value_counts()
# Out:
# Physician                     5957
# Statistician                  5806
# Web_designer                  5397
# Psychologist                  5390
# Computer_hardware_engineer    5372
# Drafter                       5359
# Magistrate                    5357
# Fashion_Designer              5304
# Air_traffic_controller        5281
# Comedian                      5259
# Industrial_Engineer           5250
# Mechanical_engineer           5217
# Chemical_engineer             5205
# Technical_writer              5195
# Hotel_Manager                 5178
# Financial_Analyst             5167
# Graphic_Designer              5166
# Flight_attendant              5128
# Biomedical_Engineer           5127
# Secretary                     5061
# Software_Developer            5053
# Petroleum_Engineer            5041
# Police_officer                5035
# Computer_operator             4990
# Politician                    4944
# Microbiologist                4881
# Technician                    4864
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Income             252000 non-null  int64
#  1   Age                252000 non-null  int64
#  2   Experience         252000 non-null  int64
#  3   House_Ownership    252000 non-null  object
#  4   Car_Ownership      252000 non-null  object
#  5   Profession         252000 non-null  object
#  6   CITY               252000 non-null  object
#  7   STATE              252000 non-null  object
#  8   CURRENT_JOB_YRS    252000 non-null  int64
#  9   CURRENT_HOUSE_YRS  252000 non-null  int64
#  10  Risk_Flag          252000 non-null  int64
#  11  skfold             252000 non-null  int64
#  12  Status             252000 non-null  object
# dtypes: int64(7), object(6)
# memory usage: 25.0+ MB

# %%
df.isna().sum()
# Out:
# Income               0
# Age                  0
# Experience           0
# House_Ownership      0
# Car_Ownership        0
# Profession           0
# CITY                 0
# STATE                0
# CURRENT_JOB_YRS      0
# CURRENT_HOUSE_YRS    0
# Risk_Flag            0
# skfold               0
# Status               0
# dtype: int64

# %%
df.head()
# Out:
#     Income  Age  Experience House_Ownership Car_Ownership  \
# 0  1303834   23           3          rented            no
# 1  7574516   40          10          rented            no
# 2  3991815   66           4          rented            no
# 3  6256451   41           2          rented           yes
# 4  5768871   47          11          rented            no
#
#             Profession             CITY           STATE  CURRENT_JOB_YRS  \
# 0  Mechanical_engineer             Rewa  Madhya_Pradesh                3
# 1   Software_Developer         Parbhani     Maharashtra                9
# 2     Technical_writer        Alappuzha          Kerala                4
# 3   Software_Developer      Bhubaneswar          Odisha                2
# 4        Civil_servant  Tiruchirappalli      Tamil_Nadu                3
#
#    CURRENT_HOUSE_YRS  Risk_Flag  skfold   Status
# 0                 13          0       3   single
# 1                 13          0       0   single
# ...

# %%
df.describe()
# Out:
#              Income            Age     Experience  CURRENT_JOB_YRS  \
# count  2.520000e+05  252000.000000  252000.000000    252000.000000
# mean   4.997117e+06      49.954071      10.084437         6.333877
# std    2.878311e+06      17.063855       6.002590         3.647053
# min    1.031000e+04      21.000000       0.000000         0.000000
# 25%    2.503015e+06      35.000000       5.000000         3.000000
# 50%    5.000694e+06      50.000000      10.000000         6.000000
# 75%    7.477502e+06      65.000000      15.000000         9.000000
# max    9.999938e+06      79.000000      20.000000        14.000000
#
#        CURRENT_HOUSE_YRS      Risk_Flag         skfold
# count      252000.000000  252000.000000  252000.000000
# mean           11.997794       0.123000       2.000000
# std             1.399037       0.328438       1.414216
# min            10.000000       0.000000       0.000000
# 25%            11.000000       0.000000       1.000000
# ...

# %% [markdown]
# In this describe function we can have a depth inside.
# 1. minimum salary of a person
# 2. Avg salary , maximun
# 3. Age is 21, that is a minimum age
# 4. From exprience i can say that here freshers also appling for loan.
# 5. people are staying at the place min 10 years.
# and many more.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.scatterplot(data=df, x="Age", y="Income",hue='Status')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>
# C:\Users\Debjit\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(data=df, x="Experience", y="Income",hue='Status')
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Income'>
# C:\Users\Debjit\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(data=df, x="CURRENT_JOB_YRS", y="CURRENT_HOUSE_YRS",hue='Status')
# Out:
# <AxesSubplot:xlabel='CURRENT_JOB_YRS', ylabel='CURRENT_HOUSE_YRS'>
# C:\Users\Debjit\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=df, x="Income", kde=True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=df, x="Age", kde=True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=df, x="Experience",  kde=True)
plt.show()

# %%
sns.pairplot(df,hue="Status")

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Status", y="Income", hue="Car_Ownership",
                 data=df, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Status", y="Age", hue="Car_Ownership",
                 data=df, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Status", y="Experience", hue="Car_Ownership",
                 data=df, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Status", y="CURRENT_JOB_YRS", hue="Car_Ownership",
                 data=df, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Status", y="CURRENT_HOUSE_YRS", hue="Car_Ownership",
                 data=df, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Status", y="CURRENT_HOUSE_YRS", hue="Risk_Flag",
                 data=df, palette="Set2")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="Status", y="Income", hue="Risk_Flag",
                 data=df, palette="Set1")
plt.show()

# %%
sns.violinplot(x="Status", y="Income", data=df)
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Income'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Status", hue="Experience", data=df)
plt.show()

# %%
df.to_csv("loan_prediction.csv")
